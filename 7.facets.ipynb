# %%
library(ggplot2)
library(plyr)
#load("C:/Users/6609/Documents/data.rData")
coffeechain <- read.csv("data/coffeechain.csv")

# %%
ggplot(coffeechain,aes(x=Market,y=Profit)) + geom_bar(stat="identity") + facet_grid(. ~ Product.Type)
# Out:
# Warning message:
# : Stacking not well defined when ymin != 0
# plot without title

# %%
ggplot(coffeechain,aes(x=Market,y=Profit, fill=Market)) + geom_bar(stat="identity") + facet_grid(. ~ Product.Type)
# Out:
# Warning message:
# : Stacking not well defined when ymin != 0
# plot without title
