# %%
library(ggplot2)
library(plyr)
#load("C:/Users/6609/Documents/data.rData")
Sample <- read.csv("data/Sample.csv")

# %%
ggplot(Sample,aes(x=Product.Container,y=Unit.Price)) + geom_boxplot(
) + coord_flip() +scale_y_continuous(limits=c(0,7000),breaks=seq(0, 7000, 500)) + scale_x_discrete(
    limits=rev(levels(Sample$Product.Container)))
# Out:
# plot without title
